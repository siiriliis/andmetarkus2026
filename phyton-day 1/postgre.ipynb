# %% [markdown]
# # Postgre baasist andmete pärimine

# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 3.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.8 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 3.3 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psycopg2
import pandas as pd

# %%
try:
    conn = psycopg2.connect(
        host="localhost",
        database="Cafe", 
        user="postgres", 
        password="potsataja"
    )
    df = pd.read_sql_query("SELECT * FROM cafe_sales.cafe_sales_cleaned", conn)
    conn.close()
except:
    print("Sorry ei leia")
# Out:
# C:\Users\Sipsik\AppData\Local\Temp\ipykernel_10500\3244936248.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM cafe_sales.cafe_sales_cleaned", conn)

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:potsataja@localhost/cafe")
df = pd.read_sql_query("SELECT * FROM cafe_sales.cafe_budget", engine)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from sqlalchemy import create_engine
#       2 engine = create_engine("postgresql://postgres:potsataja@localhost/cafe")
#       3 df = pd.read_sql_query("SELECT * FROM cafe_sales.cafe_budget", engine)
#
# ModuleNotFoundError: No module named 'sqlalchemy'
